# %%
#equilibrium.ipynb
#by Joe Hahn, jmh.datasciences@gmail.com, 21 March 2018.
#compare simulated fixed point to that predicted by BGT, for various ring masses

# %%
#restore output
parent_folders = [
    'narrow_ring/ring_mass_1.5e-11/', 'narrow_ring/ring_mass_2.0e-11/', 'narrow_ring/ring_mass_3.7e-11/', 
    'narrow_ring/ring_mass_5.0e-11/', 'narrow_ring/ring_mass_1.0e-10/', 'narrow_ring/ring_mass_2.5e-10/', 
    'narrow_ring/ring_mass_5.0e-10/', 'narrow_ring/ring_mass_1.0e-9/', 'narrow_ring/ring_mass_2.0e-9/', 
    'wide_ring/ring_mass_1.0e-10/', 'wide_ring/ring_mass_2.0e-10/', 'wide_ring/ring_mass_3.3e-10/', 
    'wide_ring/ring_mass_5.0e-10/', 'wide_ring/ring_mass_7.0e-10/', 'wide_ring/ring_mass_1.0e-9/', 
    'wide_ring/ring_mass_1.5e-9/', 'wide_ring/ring_mass_2.0e-9/', 'wide_ring/ring_mass_3.3e-9/', 
    'wide_ring/ring_mass_7.0e-9/', 'wide_ring/ring_mass_8.5e-9/']
total_ring_masses = []
da_list = []
de_list = []
dwt_list = []
a_avg_list = []
e_avg_list = []
de_eq_bgt_list = []
de_eq_list = []
from helper_fns import *
from libration import *
for parent_folder in parent_folders:
    #read simulation output
    input_file = parent_folder + "inputs.py"
    execfile(input_file)
    the_output_folder = parent_folder + output_folder
    print 'reading output in folder = ', the_output_folder
    r, t, vr, vt, times, lambda0 = restore_output(the_output_folder)
    a, e, wt, M = coords2elem(J2, Rp, r, t, vr, vt)
    print 'r.shape = ', r.shape
    print 'radial_width = ', radial_width
    print 'total_ring_mass = ', total_ring_mass
    print 'initial_orbits = ', initial_orbits
    total_ring_masses += [total_ring_mass]
    #calculate differences da, de, dwt between outer & inner streamline's periapse
    a_inner, a_outer, a_mean, da, e_inner, e_outer, e_mean, de, wt_inner, wt_outer, dwt = \
        orbit_deltas(times, r, t, vr, vt, a, e, wt, J2, Rp)
    da_list += [da.mean()]
    de_list += [de.mean()]
    dwt_list += [dwt.mean()]
    a_avg_list += [a_mean.mean()]
    e_avg_list += [e_mean.mean()]
    #equilibrium de
    de_eq = np.median(de)
    de_eq_list += [de_eq]
    #lowest-order q and H(q2)
    H, q, e_prime, wt_prime = calculate_Hq(a_mean, e_mean, da, de, dwt)
    H_avg = np.median(H)
    q_avg = np.median(q)
    print 'H_avg = ', H_avg
    print 'q_avg = ', q_avg
    #BGT's equilibrium de
    M_central = 1.0
    Ra = (Rp/a_mean).mean()
    da_over_a = (da/a_mean).mean()
    de_eq_bgt = (21.0/4)*np.pi*e_mean.mean()*J2*(M_central/total_ring_mass)*(Ra**2)*(da_over_a**3)/H_avg
    de_eq_bgt_list += [de_eq_bgt]
    print 'equilibrium de_eq = ', de_eq
    print 'equilibrium de_eq_bgt = ', de_eq_bgt
ring_masses = np.array(total_ring_masses)
de_eq = np.array(de_eq_list)
de_eq_bgt = np.array(de_eq_bgt_list)
a = np.array(a_avg_list)
da = np.array(da_list)
a = np.array(a_avg_list)
dw = np.array(dwt_list)
adeda_eq = a*de_eq/da
adeda_eq_bgt = a*de_eq_bgt/da
# Out:
# reading output in folder =  narrow_ring/ring_mass_1.5e-11/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.0005
# total_ring_mass =  1.5e-11
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.0025, 'e_prime': 0.9115776941703618}
# H_avg =  1.8754763339253353
# q_avg =  0.9229229648506381
# equilibrium de_eq =  0.000461094704054242
# equilibrium de_eq_bgt =  0.00045740576161620096
# reading output in folder =  narrow_ring/ring_mass_2.0e-11/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.0005
# total_ring_mass =  2e-11
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.0025, 'e_prime': 0.8784931024649381}
# H_avg =  1.447937828610341
# q_avg =  0.8827384864851512
# equilibrium de_eq =  0.0004412443618696457
# equilibrium de_eq_bgt =  0.0004444281903351228
# reading output in folder =  narrow_ring/ring_mass_3.7e-11/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.0005
# total_ring_mass =  3.7e-11
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.0025, 'e_prime': 0.742338226814949}
# H_avg =  0.9077087841860549
# q_avg =  0.7489597002701004
# equilibrium de_eq =  0.00037435893205744423
# equilibrium de_eq_bgt =  0.0003832092630195461
# reading output in folder =  narrow_ring/ring_mass_5.0e-11/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.0005
# total_ring_mass =  5e-11
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.0025, 'e_prime': 0.6563564453222109}
# H_avg =  0.7584587918128312
# q_avg =  0.6587259012975091
# equilibrium de_eq =  0.00032930073451441265
# equilibrium de_eq_bgt =  0.0003394235056179625
# reading output in folder =  narrow_ring/ring_mass_1.0e-10/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.0005
# total_ring_mass =  1e-10
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.0025, 'e_prime': 0.4201771523671304}
# H_avg =  0.5787852822940334
# q_avg =  0.4225764385118543
# equilibrium de_eq =  0.00021125668059873747
# equilibrium de_eq_bgt =  0.0002224342267867714
# reading output in folder =  narrow_ring/ring_mass_2.5e-10/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.0005
# total_ring_mass =  2.5e-10
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.0025, 'e_prime': 0.17645898543956515}
# H_avg =  0.5122450129357979
# q_avg =  0.17828974802946052
# equilibrium de_eq =  8.914467125485529e-05
# equilibrium de_eq_bgt =  0.00010058832487562364
# reading output in folder =  narrow_ring/ring_mass_5.0e-10/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.0005
# total_ring_mass =  5e-10
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.0025, 'e_prime': 0.08010714324639183}
# H_avg =  0.5024026173072409
# q_avg =  0.07983072287682251
# equilibrium de_eq =  3.9930539148346714e-05
# equilibrium de_eq_bgt =  5.13300205599171e-05
# reading output in folder =  narrow_ring/ring_mass_1.0e-9/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.0005
# total_ring_mass =  1e-09
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.0025, 'e_prime': 0.028714560556256274}
# H_avg =  0.500312309071894
# q_avg =  0.02884868412644703
# equilibrium de_eq =  1.4438910658660323e-05
# equilibrium de_eq_bgt =  2.5821391326996966e-05
# reading output in folder =  narrow_ring/ring_mass_2.0e-9/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.0005
# total_ring_mass =  2e-09
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.0025, 'e_prime': 0.0031692465881401244}
# H_avg =  0.5000038894614554
# q_avg =  0.00322052875998172
# equilibrium de_eq =  1.6104577662424263e-06
# equilibrium de_eq_bgt =  1.2968222891791573e-05
# reading output in folder =  wide_ring/ring_mass_1.0e-10/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  1e-10
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.9434810417541142}
# H_avg =  2.284463247621319
# q_avg =  0.9442251183618662
# equilibrium de_eq =  0.0009438263671482225
# equilibrium de_eq_bgt =  0.0009004354495244467
# reading output in folder =  wide_ring/ring_mass_2.0e-10/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  2e-10
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.8407186869479142}
# H_avg =  1.199666565333095
# q_avg =  0.8410584456932092
# equilibrium de_eq =  0.000840731778063734
# equilibrium de_eq_bgt =  0.0008574069717784134
# reading output in folder =  wide_ring/ring_mass_3.3e-10/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  3.3e-10
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.7036234978019262}
# H_avg =  0.8361336114870946
# q_avg =  0.7116940635329871
# equilibrium de_eq =  0.0007112627407971049
# equilibrium de_eq_bgt =  0.0007454284723183872
# reading output in folder =  wide_ring/ring_mass_5.0e-10/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  5e-10
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.5730926192199525}
# H_avg =  0.6711710263048184
# q_avg =  0.5737003315805962
# equilibrium de_eq =  0.0005735201350119835
# equilibrium de_eq_bgt =  0.000613158555859127
# reading output in folder =  wide_ring/ring_mass_7.0e-10/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  7e-10
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.4479869372297164}
# H_avg =  0.5930560593587721
# q_avg =  0.4530850462992101
# equilibrium de_eq =  0.0004529051636857403
# equilibrium de_eq_bgt =  0.0004956636274611008
# reading output in folder =  wide_ring/ring_mass_1.0e-9/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  1e-09
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.328605016917467}
# H_avg =  0.5458362820844443
# q_avg =  0.33298690556221244
# equilibrium de_eq =  0.0003328822203067022
# equilibrium de_eq_bgt =  0.00037709171556787045
# reading output in folder =  wide_ring/ring_mass_1.5e-9/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  1.5e-09
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.22049900967091757}
# H_avg =  0.5188607051769424
# q_avg =  0.21969977121118464
# equilibrium de_eq =  0.00021969846278211726
# equilibrium de_eq_bgt =  0.00026463175279543713
# reading output in folder =  wide_ring/ring_mass_2.0e-9/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  2e-09
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.15757847554672025}
# H_avg =  0.5094343401513329
# q_avg =  0.15697482898793846
# equilibrium de_eq =  0.00015699700430007058
# equilibrium de_eq_bgt =  0.00020223953160486673
# reading output in folder =  wide_ring/ring_mass_3.3e-9/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  3.3e-09
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.06753842436005013}
# H_avg =  0.5023932475403181
# q_avg =  0.07967573375460386
# equilibrium de_eq =  7.888655963859612e-05
# equilibrium de_eq_bgt =  0.00012439410151482967
# reading output in folder =  wide_ring/ring_mass_7.0e-9/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  7e-09
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.013510769373252943}
# H_avg =  0.5000702968718039
# q_avg =  0.013690472775756139
# equilibrium de_eq =  1.3710851904690131e-05
# equilibrium de_eq_bgt =  5.9144733088884913e-05
# reading output in folder =  wide_ring/ring_mass_8.5e-9/output
# r.shape =  (1001, 2, 241)
# radial_width =  0.001
# total_ring_mass =  8.5e-09
# initial_orbits =  {'w_prime': 0.0, 'shape': 'eccentric', 'e': 0.005, 'e_prime': 0.003544403676889423}
# H_avg =  0.5000042942300026
# q_avg =  0.003383957728001373
# equilibrium de_eq =  3.3801803211207584e-06
# equilibrium de_eq_bgt =  4.878438604677855e-05

# %%
#prep plots
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
sns.set(font_scale=1.5, font='DejaVu Sans')
import numpy as np

# %%
#plot de_eq vs total_ring_masses
x = ring_masses
y = de_eq_bgt
f, ax = plt.subplots(figsize=(10, 6))
p = ax.plot(x, y, marker='o', markersize=6, linestyle='-', linewidth=2, label='theory')
y = de_eq
p = ax.plot(x, y, marker='o', markersize=6, linestyle='-', linewidth=2, label='simulation')
p = ax.set_title(r'equilibrium $\Delta e$')
p = ax.set_xlabel('ringlet mass    (central mass)')
p = ax.set_ylabel(r'equilibrium $\Delta e$')
p = ax.set_xlim(8.0e-12, 1.5e-8)
p = ax.set_xscale('log')
p = plt.legend()

# %%
#plot adeda_eq vs total_ring_masses
x = ring_masses
y = adeda_eq_bgt
f, ax = plt.subplots(figsize=(10, 6))
p = ax.plot(x, y, marker='o', markersize=6, linestyle='-', linewidth=2, label='theory')
y = adeda_eq
p = ax.plot(x, y, marker='o', markersize=6, linestyle='-', linewidth=2, label='simulation')
p = ax.set_xlabel(r'ringlet mass $m_r$')
p = ax.set_ylabel(r"equilibrium $e'$")
p = ax.set_xlim(8.0e-12, 1.5e-8)
p = ax.set_ylim(-0.05, 1.05)
p = ax.set_xscale('log')
p = plt.legend()
plt.savefig('figs/equilibrium.pdf', bbox_inches='tight')
